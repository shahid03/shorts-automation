# %%
# @title 🚀 Start ComfyUI with Tunnel
import os
import time
import subprocess
from IPython.utils import capture

# 1. Install ComfyUI and Dependencies
print("⏳ Installing ComfyUI...")
# !git clone https://github.com/comfyanonymous/ComfyUI
# %cd ComfyUI
# !pip install -r requirements.txt

# 2. Download the Model (Realistic Stock Photo v2.0)
print("⬇️ Downloading Model...")
# !wget -O models/checkpoints/realisticStockPhoto_v20.safetensors https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors

# 3. Install Cloudflare Tunnel
print("wc Installing Cloudflared...")
# !wget -q -nc https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64.deb
# !dpkg -i cloudflared-linux-amd64.deb

# 4. Run ComfyUI in Background
print("🚀 Starting ComfyUI Server...")
# Run on port 8188 in the background
subprocess.Popen(["python", "main.py", "--port", "8188"], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# Wait for server to start
time.sleep(10)

# 5. Start Tunnel
print("🔗 Creating Public URL...")
# This will output a URL like https://random-words.trycloudflare.com
# !cloudflared tunnel --url http://127.0.0.1:8188
# Out:
# ⏳ Installing ComfyUI...
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 29140, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 29140 (delta 31), reused 26 (delta 26), pack-reused 29098 (from 2)
# Receiving objects: 100% (29140/29140), 69.37 MiB | 23.81 MiB/s, done.
# Resolving deltas: 100% (19787/19787), done.
# /content/ComfyUI/ComfyUI
# ...
# ⬇️ Downloading Model...
# --2025-12-27 21:30:27--  https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/realisticStockPhoto_v20.safetensors
# Resolving huggingface.co (huggingface.co)... 3.165.160.59, 3.165.160.11, 3.165.160.12, ...
# Connecting to huggingface.co (huggingface.co)|3.165.160.59|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...
